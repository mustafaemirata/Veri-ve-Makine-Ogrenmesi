# %%
import pandas as pd

# %%
df=pd.read_csv("pokemon.csv")

# %%
df
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318   45      49       49
# 1      2              Ivysaur    Grass  Poison    405   60      62       63
# 2      3             Venusaur    Grass  Poison    525   80      82       83
# 3      4           Charmander     Fire     NaN    309   39      52       43
# 4      5           Charmeleon     Fire     NaN    405   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 737  738              Zygarde   Dragon  Ground    600  108     100      121
# 738  739              Diancie     Rock   Fairy    600   50     100      150
# 739  740  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 740  741   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 741  742            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     65           1      False
# 4     80           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 737  738              Zygarde   Dragon  Ground    600  108     100      121
# 738  739              Diancie     Rock   Fairy    600   50     100      150
# 739  740  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 740  741   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 741  742            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 737       81       95     95           6       True
# 738      100      150     50           6       True
# 739      150      130     70           6       True
# 740      170      130     80           6       True
# 741      130       90     70           6       True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           742 non-null    int64
#  1   Name        742 non-null    object
#  2   Type 1      742 non-null    object
#  3   Type 2      368 non-null    object
#  4   Total       742 non-null    int64
#  5   HP          742 non-null    int64
#  6   Attack      742 non-null    int64
#  7   Defense     742 non-null    int64
#  8   Sp. Atk     742 non-null    int64
#  9   Sp. Def     742 non-null    int64
#  10  Speed       742 non-null    int64
#  11  Generation  742 non-null    int64
#  12  Legendary   742 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 70.4+ KB

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  742.000000  742.00000  742.000000  742.000000  742.000000  742.000000
# mean   371.500000  422.71159   68.699461   75.803235   71.439353   70.113208
# std    214.341239  111.89932   25.979645   29.657225   29.467766   29.979536
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    186.250000  325.00000   50.000000   55.000000   50.000000   45.250000
# 50%    371.500000  430.00000   65.000000   75.000000   67.000000   65.000000
# 75%    556.750000  500.00000   80.000000   95.000000   89.750000   90.000000
# max    742.000000  720.00000  255.000000  180.000000  230.000000  180.000000
#
#           Sp. Def       Speed  Generation
# count  742.000000  742.000000  742.000000
# mean    70.088949   66.567385    3.358491
# std     27.308952   27.899185    1.660302
# min     20.000000    5.000000    1.000000
# 25%     50.000000   45.000000    2.000000
# ...

# %%
df.describe().transpose
# Out:
# <bound method DataFrame.transpose of                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  742.000000  742.00000  742.000000  742.000000  742.000000  742.000000
# mean   371.500000  422.71159   68.699461   75.803235   71.439353   70.113208
# std    214.341239  111.89932   25.979645   29.657225   29.467766   29.979536
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    186.250000  325.00000   50.000000   55.000000   50.000000   45.250000
# 50%    371.500000  430.00000   65.000000   75.000000   67.000000   65.000000
# 75%    556.750000  500.00000   80.000000   95.000000   89.750000   90.000000
# max    742.000000  720.00000  255.000000  180.000000  230.000000  180.000000
#
#           Sp. Def       Speed  Generation
# count  742.000000  742.000000  742.000000
# mean    70.088949   66.567385    3.358491
# std     27.308952   27.899185    1.660302
# min     20.000000    5.000000    1.000000
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=742, step=1)

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df["Name"]
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3               Charmander
# 4               Charmeleon
#               ...
# 737                Zygarde
# 738                Diancie
# 739    HoopaHoopa Confined
# 740     HoopaHoopa Unbound
# 741              Volcanion
# Name: Name, Length: 742, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["Attack"])
# Out:
# pandas.core.series.Series

# %%
df[["Name","Type 1"]]
# Out:
#                     Name   Type 1
# 0              Bulbasaur    Grass
# 1                Ivysaur    Grass
# 2               Venusaur    Grass
# 3             Charmander     Fire
# 4             Charmeleon     Fire
# ..                   ...      ...
# 737              Zygarde   Dragon
# 738              Diancie     Rock
# 739  HoopaHoopa Confined  Psychic
# 740   HoopaHoopa Unbound  Psychic
# 741            Volcanion     Fire
#
# [742 rows x 2 columns]

# %% [markdown]
# # Drop

# %%
poke=df.iloc[148]
poke
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 poke=df.iloc[148]
#       2 poke
#
# File c:\Users\mustafa\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\mustafa\anaconda3\Lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# ...

# %%
df[140:155]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary, Total Atk, hp ratio %, 0]
# Index: []

# %% [markdown]
# # Append

# %% [markdown]
#  # Index Operasyonları

# %%
df.head()
# Out:
#       # Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 752 NaN  NaN    NaN    NaN    NaN NaN     NaN      NaN      NaN      NaN
# 753 NaN  NaN    NaN    NaN    NaN NaN     NaN      NaN      NaN      NaN
# 754 NaN  NaN    NaN    NaN    NaN NaN     NaN      NaN      NaN      NaN
# 755 NaN  NaN    NaN    NaN    NaN NaN     NaN      NaN      NaN      NaN
# 756 NaN  NaN    NaN    NaN    NaN NaN     NaN      NaN      NaN      NaN
#
#      Speed  Generation Legendary  Total Atk  hp ratio %         0
# 752    NaN         NaN       NaN        NaN         NaN       130
# 753    NaN         NaN       NaN        NaN         NaN         1
# 754    NaN         NaN       NaN        NaN         NaN      True
# 755    NaN         NaN       NaN        NaN         NaN       264
# 756    NaN         NaN       NaN        NaN         NaN  1.177778

# %%
df.iloc[32:35]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary, Total Atk, hp ratio %, 0]
# Index: []

# %% [markdown]
# ## Koşul Ekleme Ve and Or
